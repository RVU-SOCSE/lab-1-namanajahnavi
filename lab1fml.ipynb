# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import warnings

warnings.filterwarnings("ignore")

# %%
# Dataset
X = np.array([1, 2, 3]).reshape(-1, 1)
y = np.array([1, 4, 9])
#True relationship  y = x^2

# %%
model_1 = LinearRegression()
model_1.fit(X, y)
print("Slope:", model_1.coef_)
print("Intercept:", model_1.intercept_)
# Out:
# Slope: [4.]
# Intercept: -3.3333333333333304

# %%
print("Model_1 Predictions:", model_1.predict(X))
# Out:
# Model_1 Predictions: [0.66666667 4.66666667 8.66666667]

# %%
x = np.array([1, 2, 3])
y = np.array([1, 4, 9])

# coefficients
coeff = np.polyfit(x, y, 5)

print(coeff)
# Out:
# [-0.0021802   0.00989485  0.08919214  0.41369398  1.05373655 -0.56433732]

# %%
poly = np.poly1d(coeff)
y_pred_train = poly(x)
print("Predictions on training data:", y_pred_train)
# Out:
# Predictions on training data: [1. 4. 9.]

# %%
x_test = 4
y_true = 16
y_pred_test = poly(x_test)
print("Prediction at x=4:", y_pred_test)
print("True value:", y_true)
# Out:
# Prediction at x=4: 16.27856544088833
# True value: 16

# %% [markdown]
# **linear**

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error

# %%
x = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)
y = np.array([52, 55, 61, 70, 82])

# %%
model_11 = LinearRegression()
model_11.fit(x, y)
print("Slope:", model_11.coef_)
print("Intercept:", model_11.intercept_)
# Out:
# Slope: [7.5]
# Intercept: 41.50000000000001

# %%
model_11 = LinearRegression()
model_11.fit(x, y)
y_pred_lin = model_11.predict(x)

# %%
print("Model_1 Predictions:", model_11.predict(x))
# Out:
# Model_1 Predictions: [49.  56.5 64.  71.5 79. ]

# %%
plt.scatter(x, y)
plt.plot(x, y_pred_lin)

# %% [markdown]
# high bias low variance

# %% [markdown]
# **polynomial**

# %%
poly = PolynomialFeatures(degree=4)
x_poly = poly.fit_transform(x)

poly_reg = LinearRegression()
poly_reg.fit(x_poly, y)

y_pred_poly = poly_reg.predict(x_poly)

# %%
x_test = np.array([[6]])

lin_pred = lin_reg.predict(x_test)
poly_pred = poly_reg.predict(poly.transform(x_test))

print("Linearprediction:", lin_pred[0])
print("Polynomialprediction:", poly_pred[0])
# Out:
# Linearprediction: 86.5
# Polynomialprediction: 96.99999999999994

# %%
msel = mean_squared_error(y, y_pred_lin)
msep = mean_squared_error(y, y_pred_poly)

print("msel:", msel)
print("msep:", msep)
# Out:
# msel: 6.299999999999992
# msep: 5.755529164492502e-28

# %%
plt.scatter(x, y)
plt.plot(x, y_pred_poly)

# %% [markdown]
# low bias high variance

# %% [markdown]
# **model 1 has high bias**,
# **model 2 has high  variance**
